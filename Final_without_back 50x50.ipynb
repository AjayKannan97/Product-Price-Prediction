# %%
import glob
import numpy as np
from pprint import pprint 
folder=glob.glob("./data/*")
folder=sorted(folder, key=lambda s: s.lower())
for f in folder:
    print f
# Out:
# ./data/AAFREEN
# ./data/aanyaa cotton
# ./data/aditisitara
# ./data/AFREEN
# ./data/AKIRA
# ./data/ananya
# ./data/ANNIKA
# ./data/ARABELLA
# ./data/ayesha
# ./data/AYESHA 5
# ./data/ayesha baby
# ./data/AYSHA PAT HOUSE 32
# ./data/babydoll
# ./data/babydoll 16
# ./data/babydoll 22
# ./data/BALAJI SPARK
# ./data/BANDHAN
# ./data/BATIK
# ./data/BATIK KAPIL
# ./data/BATIK PRIYANKA
# ./data/BREEZER
# ./data/BREZZER
# ./data/bull bull
# ./data/Celebration 2
# ./data/chief guest
# ./data/chief guest2
# ./data/classy cotton
# ./data/cotton plus 3
# ./data/DD 2
# ./data/DD 3
# ./data/DD 4
# ./data/DD 5
# ./data/DD 6
# ./data/DD 7
# ./data/DD 8
# ./data/DD 9
# ./data/DEEPTEX BANDNI
# ./data/DEEPTEX BANDNI CHUNARI
# ./data/DEVI BATIK
# ./data/dolly 11
# ./data/DOLLY 13
# ./data/DOLLY 15
# ./data/DOLLY 19
# ./data/DOLLY BATIK
# ./data/elegant ayesha 3
# ./data/feelings
# ./data/GANESA 13
# ./data/GANESA PATIALA 1
# ./data/GANESA PATIALA 2
# ./data/GAZAL
# ./data/HOT SHOT
# ./data/HOTSTAR
# ./data/ISHQ E AYESHA 4
# ./data/jalwa 1
# ./data/jalwa 2
# ./data/jodha
# ./data/jodha 2
# ./data/jugni
# ./data/KANISHKA DESIRE
# ./data/KAPIL CRYSTAL
# ./data/KAPIL DD8
# ./data/KARISHMA HOUSE
# ./data/KAVYANJALI 2
# ./data/KILLERS
# ./data/LOOKWELL MANNAT
# ./data/LOOKWELL RADIANCE
# ./data/lotus
# ./data/LT NISHTA 93
# ./data/man pasand
# ./data/MANPASAND 3
# ./data/MARRYGOLD
# ./data/MASTANI SAREE
# ./data/MAYUR KUSHI
# ./data/MCM
# ./data/MEENAXI
# ./data/MEENAXI 2
# ./data/MINTOOSI
# ./data/MISS
# ./data/NAMO 3
# ./data/NAMO 4
# ./data/NAMO ANURADHA
# ./data/NAMO NEW
# ./data/Namo sarees 1
# ./data/Namo sarees 2
# ./data/nandanee
# ./data/navya cotton
# ./data/notebook
# ./data/OVER DEMAND
# ./data/OVERDEMAND 2
# ./data/OVERDEMAND 5
# ./data/OVERDEMAND 7
# ./data/padmashree
# ./data/padmashree 2
# ./data/PADMASHREE 3
# ./data/PADMASHREE 4
# ./data/PAL PAL
# ./data/PANDHADI
# ./data/pantahouse41
# ./data/Pantahouse42
# ./data/patiala house 30
# ./data/Patiala house 34
# ./data/PATIALA HOUSE 50
# ./data/PATIALA JUNCTION
# ./data/pATTU MODEL
# ./data/Pattu model 3
# ./data/pichkari
# ./data/preyanshi patiala
# ./data/PRINCESS COTTON
# ./data/PRIYANKA BW
# ./data/QUEEN
# ./data/QUEEN 6
# ./data/queen patiala 5
# ./data/RAASLEELA 13
# ./data/RAASLEELA 14
# ./data/raasleela nx
# ./data/red cherry
# ./data/RELISH
# ./data/RELISH 6
# ./data/RELISH 8
# ./data/ROSEMEEN
# ./data/ROYAL BABY
# ./data/RUDRA
# ./data/rudra bandhani
# ./data/safari
# ./data/SAKHI
# ./data/sanjeeda
# ./data/sehzadi
# ./data/selfie
# ./data/selfie 2
# ./data/selina
# ./data/SOLITAIRE
# ./data/sree bairav
# ./data/SUMMER COOL
# ./data/sunheri
# ./data/SUPERHIT
# ./data/suryajyothi
# ./data/sweety
# ./data/TRENDY COTTON 33
# ./data/ZALAK
# ./data/zion

# %%
price=np.loadtxt('price.txt')
print price
# Out:
# [[ 495.    1.    1.    0.]
#  [ 405.    1.    1.    0.]
#  [ 640.    0.    2.    0.]
#  [ 540.    1.    1.    0.]
#  [ 485.    1.   10.    0.]
#  [ 310.    1.    2.    0.]
#  [ 310.    1.    2.    1.]
#  [ 350.    1.    2.    0.]
#  [ 870.    0.   10.    1.]
#  [ 830.    0.   10.    1.]
#  [ 535.    1.   10.    1.]
#  [ 914.    0.   10.    0.]
#  [ 555.    1.    1.    1.]
#  [ 535.    1.    1.    1.]
#  [ 555.    1.   10.    0.]
#  [ 465.    0.   10.    0.]
#  [ 310.    1.    2.    0.]
#  [ 460.    1.    0.    0.]
#  [ 430.    1.    0.    1.]
#  [ 405.    1.    0.    0.]
#  [ 345.    0.    2.    1.]
#  [ 685.    1.   10.    0.]
#  [ 430.    1.   10.    0.]
#  [ 610.    0.   10.    1.]
#  [ 400.    1.    2.    0.]
#  [ 385.    1.    2.    0.]
#  [ 320.    1.    2.    0.]
#  [ 605.    0.   10.    0.]
#  [ 455.    1.   10.    0.]
#  [ 455.    1.   10.    1.]
#  [ 450.    1.    1.    0.]
#  [ 445.    1.    1.    0.]
#  [ 445.    1.    1.    1.]
#  [ 445.    1.    1.    0.]
#  [ 455.    1.   10.    0.]
#  [ 455.    1.   10.    0.]
#  [ 345.    1.    0.    0.]
#  [ 345.    1.    0.    0.]
#  [ 435.    1.    0.    0.]
#  [ 560.    1.    1.    0.]
#  [ 561.    1.    1.    0.]
#  [ 550.    1.    1.    0.]
#  [ 545.    1.    1.    0.]
#  [ 320.    1.    0.    0.]
#  [ 835.    0.   10.    1.]
#  [ 425.    0.    1.    0.]
#  [ 295.    1.    2.    0.]
#  [ 330.    1.    2.    0.]
#  [ 320.    1.    2.    0.]
#  [ 465.    1.   10.    0.]
#  [ 340.    1.    2.    0.]
#  [ 450.    1.    1.    0.]
#  [ 880.    0.   10.    1.]
#  [ 785.    0.   10.    1.]
#  [ 785.    0.   10.    1.]
#  [ 810.    0.   10.    0.]
#  [ 805.    0.   10.    0.]
#  [ 440.    1.   10.    0.]
#  [ 505.    1.    1.    0.]
#  [ 430.    1.   10.    0.]
#  [ 440.    1.   10.    0.]
#  [ 620.    0.    1.    0.]
        img=img.resize((50,50), Image.ANTIALIAS)
        newim=np.asarray(img)
        '''break
        b=plt.imread(i)
        '''
        b=newim.flatten()
        im.append(b)
        p.append(price[q][0])
        w.append(price[q][1])
        h.append(price[q][2])
        c.append(price[q][3])
    q=q+1

print im[0],p[0],w[0],h[0],c[0]
# Out:
# [255 255 255 ..., 255 255 255] 495.0 1.0 1.0 0.0

# %%
print np.shape(im)
# Out:
# (1756, 7500)

# %%
print len(im)
from sklearn.svm import SVR
svr = SVR(kernel='rbf', C=1e3, gamma=0.1)
# Out:
# 1756

# %%
oe1=0.0
oe2=0.0
for i in range(10):
    from keras.models import Sequential
    from keras.layers import Dense, Activation
    m=Sequential()
    m.add(Dense(1000,input_dim=7500))
    m.add(Activation('relu'))
    m.add(Dense(100))
    m.add(Activation('relu'))
    m.add(Dense(1))
    m.add(Activation('relu'))

    m.compile(loss='mean_absolute_percentage_error',optimizer='sgd')
    
    #print len(im)
    from sklearn.svm import SVR
    svr = SVR(kernel='rbf', C=1e3, gamma=0.1)

    
    trainx=[]
    trainy=[]
    testx=[]
    testy=[]
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            temp=[]
            for l in range(7500):
                temp.append(float(im[j][l])/255)
            trainx.append(temp)
            trainy.append([p[j]])
    for j in range(i*175,i*175 + 175):
        temp=[]
        for l in range(7500):
            temp.append(float(im[j][l])/255)
        testx.append(temp)
    #testx=[im[x]/255 for x in range(i*175,i*175 + 175)]
    for j in range(i*175,i*175 + 175):
        testy.append(p[j])
    #testy=[p[x] for x in range(i*175,i*175 + 175)]    
    print np.shape(trainx)
    m.fit(trainx,trainy, epochs=10, batch_size=32)
    tp=m.predict(trainx,batch_size=16)
    #print len(tp)
    newtrainx=[]
    k=0
    #print len(tp)
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            b=[tp[k][0]]
            b.append(w[j])
            b.append(h[j])
            b.append(c[j])
            newtrainx.append(b)
            k=k+1
    svr.fit(newtrainx,trainy)
    tp=m.predict(testx,batch_size=32)
    acc=0.0
    #print ty
    for j in range(len(tp)):
        acc+=(abs(testy[j]-tp[j])/testy[j])*100
    acc=acc/len(tp)
    print acc
    oe1+=acc
    
    newtest=[]
    k=0
    for j in range(i*175,i*175+175):
        b=[tp[k][0]]
        k=k+1
        b.append(w[j])
        b.append(h[j])
        b.append(c[j])
        newtest.append(b)
    ty=svr.predict(newtest)
    acc=0.0
    #print ty
    for j in range(len(ty)):
        acc+=(abs(testy[j]-ty[j])/testy[j])*100
    acc=acc/len(ty)
    print acc
    oe2+=acc
# Out:
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 2s - loss: 44.3110
# Epoch 2/10
# 1575/1575 [==============================] - 2s - loss: 28.2690
# Epoch 3/10
# 1575/1575 [==============================] - 2s - loss: 29.5639
# Epoch 4/10
# 1575/1575 [==============================] - 2s - loss: 28.8716
# Epoch 5/10
# 1575/1575 [==============================] - 2s - loss: 28.7687
# Epoch 1/10
# 1575/1575 [==============================] - 2s - loss: 41.3750
# Epoch 2/10
# 1575/1575 [==============================] - 2s - loss: 30.0153
# Epoch 3/10
# 1575/1575 [==============================] - 4s - loss: 30.9402
# Epoch 4/10
# 1575/1575 [==============================] - 2s - loss: 29.2508
# Epoch 5/10
# 1575/1575 [==============================] - 2s - loss: 29.1037
# Epoch 6/10
# 1575/1575 [==============================] - 2s - loss: 29.4432
# Epoch 7/10
# 1575/1575 [==============================] - 2s - loss: 29.5336
# Epoch 8/10
# 1575/1575 [==============================] - 2s - loss: 28.5978
# Epoch 9/10
# 1575/1575 [==============================] - 2s - loss: 27.7181
# Epoch 10/10
# 1575/1575 [==============================] - 2s - loss: 28.7876
# [ 51.33448792]
# 18.3141761365
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 2s - loss: 42.0061
# Epoch 2/10
# 1575/1575 [==============================] - 2s - loss: 31.9904
# Epoch 3/10
# 1575/1575 [==============================] - 2s - loss: 29.2721
# Epoch 4/10
# 1575/1575 [==============================] - 2s - loss: 30.0664
# Epoch 5/10
# 1575/1575 [==============================] - 2s - loss: 27.9332
# Epoch 6/10
# 1575/1575 [==============================] - 2s - loss: 29.6970
# Epoch 7/10
# 1575/1575 [==============================] - 2s - loss: 28.0701
# Epoch 8/10
# 1575/1575 [==============================] - 2s - loss: 30.6476
# Epoch 9/10
# 1575/1575 [==============================] - 2s - loss: 30.0692
# Epoch 10/10
# 1575/1575 [==============================] - 2s - loss: 30.1897
# [ 30.60259819]
# 45.4964529045

# %%
print oe1/10
print oe2/10
# Out:
# [ 41.54169846]
# 21.4298103053

# %%
oe1=0.0
oe2=0.0
for i in range(10):
    from keras.models import Sequential
    from keras.layers import Dense, Activation
    m=Sequential()
    m.add(Dense(1000,input_dim=7500))
    m.add(Activation('relu'))
    m.add(Dense(100))
    m.add(Activation('relu'))
    m.add(Dense(1))
    m.add(Activation('relu'))

    m.compile(loss='mean_absolute_percentage_error',optimizer='adam')
    
    #print len(im)
    from sklearn.svm import SVR
    svr = SVR(kernel='rbf', C=1e3, gamma=0.1)

    
    trainx=[]
    trainy=[]
    testx=[]
    testy=[]
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            temp=[]
            for l in range(7500):
                temp.append(float(im[j][l])/255)
            trainx.append(temp)
            trainy.append([p[j]])
    for j in range(i*175,i*175 + 175):
        temp=[]
        for l in range(7500):
            temp.append(float(im[j][l])/255)
        testx.append(temp)
    #testx=[im[x]/255 for x in range(i*175,i*175 + 175)]
    for j in range(i*175,i*175 + 175):
        testy.append(p[j])
    #testy=[p[x] for x in range(i*175,i*175 + 175)]    
    print np.shape(trainx)
    m.fit(trainx,trainy, epochs=10, batch_size=32)
    tp=m.predict(trainx,batch_size=16)
    #print len(tp)
    newtrainx=[]
    k=0
    #print len(tp)
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            b=[tp[k][0]]
            b.append(w[j])
            b.append(h[j])
            b.append(c[j])
            newtrainx.append(b)
            k=k+1
    svr.fit(newtrainx,trainy)
    tp=m.predict(testx,batch_size=32)
    acc=0.0
    #print ty
    for j in range(len(tp)):
        acc+=(abs(testy[j]-tp[j])/testy[j])*100
    acc=acc/len(tp)
    print acc
    oe1+=acc
    
    newtest=[]
    k=0
    for j in range(i*175,i*175+175):
        b=[tp[k][0]]
        k=k+1
        b.append(w[j])
        b.append(h[j])
        b.append(c[j])
        newtest.append(b)
    ty=svr.predict(newtest)
    acc=0.0
    #print ty
    for j in range(len(ty)):
        acc+=(abs(testy[j]-ty[j])/testy[j])*100
    acc=acc/len(ty)
    print acc
    oe2+=acc
# Out:
# (1575, 7500)
# Epoch 1/10
#   96/1575 [>.............................] - ETA: 99s - loss: 85.7136
# /root/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:118: UserWarning: Method on_batch_end() is slow compared to the batch update (0.622259). Check your callbacks.
#   % delta_t_median)
# 1575/1575 [==============================] - 11s - loss: 33.5851
# Epoch 2/10
# 1575/1575 [==============================] - 5s - loss: 26.8051
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 25.9634
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 25.4171
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 24.2807
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 23.4601
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 23.3681
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 23.1119
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 22.2864
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 22.2971
# [ 29.53796959]
# 19.8660668509
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 7s - loss: 39.1785
# Epoch 2/10
# 1575/1575 [==============================] - 5s - loss: 29.5398
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 27.4759
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 26.4763
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 25.5239
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 25.0266
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 25.6206
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 24.1142
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 23.7769
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 23.5966
# [ 24.41944122]
# 26.779096622
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 6s - loss: 36.8151
# Epoch 2/10
# 1575/1575 [==============================] - 5s - loss: 28.7388
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 27.1790
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 26.6987
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 25.8613
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 26.1631
# 1575/1575 [==============================] - 5s - loss: 26.9780
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 26.0959
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 25.1129
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 27.2864
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 24.3984
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 24.2303
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 23.5055
# [ 29.9402256]
# 21.6923822206
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 6s - loss: 34.1774
# Epoch 2/10
# 1575/1575 [==============================] - 5s - loss: 26.6112
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 25.1936
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 24.2594
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 23.6796
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 23.1501
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 22.5556
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 22.5326
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 22.3380
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 21.4786
# [ 31.9658699]
# 21.8655524862
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 6s - loss: 100.0000
# Epoch 2/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 100.0000
# [ 100.]
# 21.1087726708
# (1575, 7500)
# Epoch 1/10
# 1575/1575 [==============================] - 6s - loss: 36.1097
# Epoch 2/10
# 1575/1575 [==============================] - 8s - loss: 27.6006
# Epoch 3/10
# 1575/1575 [==============================] - 5s - loss: 26.0513
# Epoch 4/10
# 1575/1575 [==============================] - 5s - loss: 25.2050
# Epoch 5/10
# 1575/1575 [==============================] - 5s - loss: 25.0999
# Epoch 6/10
# 1575/1575 [==============================] - 5s - loss: 23.6612
# Epoch 7/10
# 1575/1575 [==============================] - 5s - loss: 23.9302
# Epoch 8/10
# 1575/1575 [==============================] - 5s - loss: 23.3403
# Epoch 9/10
# 1575/1575 [==============================] - 5s - loss: 22.8007
# Epoch 10/10
# 1575/1575 [==============================] - 5s - loss: 22.2544
# [ 32.66060638]
# 42.737649343

# %%
print oe1/10
print oe2/10
# Out:
# [ 34.60269547]
# 23.1050259936
