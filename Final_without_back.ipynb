# %%
import glob
import numpy as np
from pprint import pprint 
folder=glob.glob("./data/*")
folder=sorted(folder, key=lambda s: s.lower())
for f in folder:
    print f
# Out:
# ./data/AAFREEN
# ./data/aanyaa cotton
# ./data/aditisitara
# ./data/AFREEN
# ./data/AKIRA
# ./data/ananya
# ./data/ANNIKA
# ./data/ARABELLA
# ./data/ayesha
# ./data/AYESHA 5
# ./data/ayesha baby
# ./data/AYSHA PAT HOUSE 32
# ./data/babydoll
# ./data/babydoll 16
# ./data/babydoll 22
# ./data/BALAJI SPARK
# ./data/BANDHAN
# ./data/BATIK
# ./data/BATIK KAPIL
# ./data/BATIK PRIYANKA
# ./data/BREEZER
# ./data/BREZZER
# ./data/bull bull
# ./data/Celebration 2
# ./data/chief guest
# ./data/chief guest2
# ./data/classy cotton
# ./data/cotton plus 3
# ./data/DD 2
# ./data/DD 3
# ./data/DD 4
# ./data/DD 5
# ./data/DD 6
# ./data/DD 7
# ./data/DD 8
# ./data/DD 9
# ./data/DEEPTEX BANDNI
# ./data/DEEPTEX BANDNI CHUNARI
# ./data/DEVI BATIK
# ./data/dolly 11
# ./data/DOLLY 13
# ./data/DOLLY 15
# ./data/DOLLY 19
# ./data/DOLLY BATIK
# ./data/elegant ayesha 3
# ./data/feelings
# ./data/GANESA 13
# ./data/GANESA PATIALA 1
# ./data/GANESA PATIALA 2
# ./data/GAZAL
# ./data/HOT SHOT
# ./data/HOTSTAR
# ./data/ISHQ E AYESHA 4
# ./data/jalwa 1
# ./data/jalwa 2
# ./data/jodha
# ./data/jodha 2
# ./data/jugni
# ./data/KANISHKA DESIRE
# ./data/KAPIL CRYSTAL
# ./data/KAPIL DD8
# ./data/KARISHMA HOUSE
# ./data/KAVYANJALI 2
# ./data/KILLERS
# ./data/LOOKWELL MANNAT
# ./data/LOOKWELL RADIANCE
# ./data/lotus
# ./data/LT NISHTA 93
# ./data/man pasand
# ./data/MANPASAND 3
# ./data/MARRYGOLD
# ./data/MASTANI SAREE
# ./data/MAYUR KUSHI
# ./data/MCM
# ./data/MEENAXI
# ./data/MEENAXI 2
# ./data/MINTOOSI
# ./data/MISS
# ./data/NAMO 3
# ./data/NAMO 4
# ./data/NAMO ANURADHA
# ./data/NAMO NEW
# ./data/Namo sarees 1
# ./data/Namo sarees 2
# ./data/nandanee
# ./data/navya cotton
# ./data/notebook
# ./data/OVER DEMAND
# ./data/OVERDEMAND 2
# ./data/OVERDEMAND 5
# ./data/OVERDEMAND 7
# ./data/padmashree
# ./data/padmashree 2
# ./data/PADMASHREE 3
# ./data/PADMASHREE 4
# ./data/PAL PAL
# ./data/PANDHADI
# ./data/pantahouse41
# ./data/Pantahouse42
# ./data/patiala house 30
# ./data/Patiala house 34
# ./data/PATIALA HOUSE 50
# ./data/PATIALA JUNCTION
# ./data/pATTU MODEL
# ./data/Pattu model 3
# ./data/pichkari
# ./data/preyanshi patiala
# ./data/PRINCESS COTTON
# ./data/PRIYANKA BW
# ./data/QUEEN
# ./data/QUEEN 6
# ./data/queen patiala 5
# ./data/RAASLEELA 13
# ./data/RAASLEELA 14
# ./data/raasleela nx
# ./data/red cherry
# ./data/RELISH
# ./data/RELISH 6
# ./data/RELISH 8
# ./data/ROSEMEEN
# ./data/ROYAL BABY
# ./data/RUDRA
# ./data/rudra bandhani
# ./data/safari
# ./data/SAKHI
# ./data/sanjeeda
# ./data/sehzadi
# ./data/selfie
# ./data/selfie 2
# ./data/selina
# ./data/SOLITAIRE
# ./data/sree bairav
# ./data/SUMMER COOL
# ./data/sunheri
# ./data/SUPERHIT
# ./data/suryajyothi
# ./data/sweety
# ./data/TRENDY COTTON 33
# ./data/ZALAK
# ./data/zion

# %%
price=np.loadtxt('price.txt')
print price
# Out:
# [[ 495.    1.    1.    0.]
#  [ 405.    1.    1.    0.]
#  [ 640.    0.    2.    0.]
#  [ 540.    1.    1.    0.]
#  [ 485.    1.   10.    0.]
#  [ 310.    1.    2.    0.]
#  [ 310.    1.    2.    1.]
#  [ 350.    1.    2.    0.]
#  [ 870.    0.   10.    1.]
#  [ 830.    0.   10.    1.]
#  [ 535.    1.   10.    1.]
#  [ 914.    0.   10.    0.]
#  [ 555.    1.    1.    1.]
#  [ 535.    1.    1.    1.]
#  [ 555.    1.   10.    0.]
#  [ 465.    0.   10.    0.]
#  [ 310.    1.    2.    0.]
#  [ 460.    1.    0.    0.]
#  [ 430.    1.    0.    1.]
#  [ 405.    1.    0.    0.]
#  [ 345.    0.    2.    1.]
#  [ 685.    1.   10.    0.]
#  [ 430.    1.   10.    0.]
#  [ 610.    0.   10.    1.]
#  [ 400.    1.    2.    0.]
#  [ 385.    1.    2.    0.]
#  [ 320.    1.    2.    0.]
#  [ 605.    0.   10.    0.]
#  [ 455.    1.   10.    0.]
#  [ 455.    1.   10.    1.]
#  [ 450.    1.    1.    0.]
#  [ 445.    1.    1.    0.]
#  [ 445.    1.    1.    1.]
#  [ 445.    1.    1.    0.]
#  [ 455.    1.   10.    0.]
#  [ 455.    1.   10.    0.]
#  [ 345.    1.    0.    0.]
#  [ 345.    1.    0.    0.]
#  [ 435.    1.    0.    0.]
#  [ 560.    1.    1.    0.]
#  [ 561.    1.    1.    0.]
#  [ 550.    1.    1.    0.]
#  [ 545.    1.    1.    0.]
#  [ 320.    1.    0.    0.]
#  [ 835.    0.   10.    1.]
#  [ 425.    0.    1.    0.]
#  [ 295.    1.    2.    0.]
#  [ 330.    1.    2.    0.]
#  [ 320.    1.    2.    0.]
#  [ 465.    1.   10.    0.]
#  [ 340.    1.    2.    0.]
#  [ 450.    1.    1.    0.]
#  [ 880.    0.   10.    1.]
#  [ 785.    0.   10.    1.]
#  [ 785.    0.   10.    1.]
#  [ 810.    0.   10.    0.]
#  [ 805.    0.   10.    0.]
#  [ 440.    1.   10.    0.]
# %%
from PIL import Image
im=[]
p=[]
w=[]
h=[]
c=[]
q=0
for f in folder:
    files=glob.glob(f+'/*.jpg')
    for j in files:
        img=Image.open(j)
        #print img.size
        img=img.resize((30,30), Image.ANTIALIAS)
        newim=np.asarray(img)
        '''break
        b=plt.imread(i)
        '''
        b=newim.flatten()
        im.append(b)
        p.append(price[q][0])
        w.append(price[q][1])
        h.append(price[q][2])
        c.append(price[q][3])
    q=q+1

print im[0],p[0],w[0],h[0],c[0]
# Out:
# [255 255 255 ..., 255 255 255] 495.0 1.0 1.0 0.0

# %%
print len(im)
from sklearn.svm import SVR
svr = SVR(kernel='rbf', C=1e3, gamma=0.1)
# Out:
# 1756

# %%
oe1=0.0
oe2=0.0
for i in range(10):
    from keras.models import Sequential
    from keras.layers import Dense, Activation
    m=Sequential()
    m.add(Dense(600,input_dim=2700))
    m.add(Activation('relu'))
    m.add(Dense(100))
    m.add(Activation('relu'))
    m.add(Dense(1))
    m.add(Activation('relu'))

    m.compile(loss='mean_absolute_percentage_error',optimizer='adagrad')
    
    #print len(im)
    from sklearn.svm import SVR
    svr = SVR(kernel='rbf', C=1e3, gamma=0.1)

    
    trainx=[]
    trainy=[]
    testx=[]
    testy=[]
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            temp=[]
            for l in range(2700):
                temp.append(float(im[j][l])/255)
            trainx.append(temp)
            trainy.append([p[j]])
    for j in range(i*175,i*175 + 175):
        temp=[]
        for l in range(2700):
            temp.append(float(im[j][l])/255)
        testx.append(temp)
    #testx=[im[x]/255 for x in range(i*175,i*175 + 175)]
    for j in range(i*175,i*175 + 175):
        testy.append(p[j])
    #testy=[p[x] for x in range(i*175,i*175 + 175)]    
    print np.shape(trainx)
    m.fit(trainx,trainy, epochs=10, batch_size=32)
    tp=m.predict(trainx,batch_size=16)
    #print len(tp)
    newtrainx=[]
    k=0
    #print len(tp)
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            b=[tp[k][0]]
            b.append(w[j])
            b.append(h[j])
            b.append(c[j])
            newtrainx.append(b)
            k=k+1
    svr.fit(newtrainx,trainy)
    tp=m.predict(testx,batch_size=32)
    acc=0.0
    #print ty
    for j in range(len(tp)):
        acc+=(abs(testy[j]-tp[j])/testy[j])*100
    acc=acc/len(tp)
    print acc
    oe1+=acc
    
    newtest=[]
    k=0
    for j in range(i*175,i*175+175):
        b=[tp[k][0]]
        k=k+1
        b.append(w[j])
        b.append(h[j])
        b.append(c[j])
        newtest.append(b)
    ty=svr.predict(newtest)
    acc=0.0
    #print ty
    for j in range(len(ty)):
        acc+=(abs(testy[j]-ty[j])/testy[j])*100
    acc=acc/len(ty)
    print acc
    oe2+=acc
# Out:
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 33.4571
# Epoch 2/10
# 1575/1575 [==============================] - 1s - loss: 27.3008
# Epoch 3/10
# Epoch 7/10
# 1575/1575 [==============================] - 1s - loss: 25.1669
# Epoch 8/10
#  - ETA: 0s - loss: 23.7432
# Epoch 9/10
# 1575/1575 [==============================] - 1s - loss: 24.1583
# Epoch 10/10
# 1575/1575 [==============================] - 1s - loss: 23.8760
# [ 42.26155472]
# 21.9663251089
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 33.3364
# Epoch 2/10
# 1575/1575 [==============================] - 1s - loss: 27.7515
# Epoch 3/10
# 1575/1575 [==============================] - 1s - loss: 26.6202
# Epoch 4/10
# 1575/1575 [==============================] - 1s - loss: 26.2630
# Epoch 5/10
# 1575/1575 [==============================] - 1s - loss: 25.8860
# Epoch 6/10
# 1575/1575 [==============================] - 1s - loss: 25.3533
# Epoch 7/10
# 1575/1575 [==============================] - 1s - loss: 25.1645
# Epoch 8/10
# 1575/1575 [==============================] - 1s - loss: 24.8618
# Epoch 9/10
# 1575/1575 [==============================] - 1s - loss: 24.4386
# Epoch 10/10
# 1575/1575 [==============================] - 1s - loss: 24.2237
# [ 29.02281189]
# 20.2152825385
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 32.5650
# Epoch 2/10
# 1575/1575 [==============================] - 1s - loss: 27.2455
# Epoch 3/10
# 1575/1575 [==============================] - 1s - loss: 27.0008
# Epoch 4/10
# 1575/1575 [==============================] - 1s - loss: 25.8003
# Epoch 5/10
# 1575/1575 [==============================] - 1s - loss: 25.2859
# Epoch 6/10
# 1575/1575 [==============================] - 1s - loss: 24.9107
# Epoch 7/10
# 1575/1575 [==============================] - 1s - loss: 24.4889
# Epoch 8/10
# 1575/1575 [==============================] - 1s - loss: 24.1756
# Epoch 9/10
# 1575/1575 [==============================] - 1s - loss: 23.8218
# Epoch 10/10
# 1575/1575 [==============================] - 1s - loss: 23.7582
# [ 36.71876907]
# 40.7295259086

# %%
print oe1/10
print oe2/10
# Out:
# [ 28.22785568]
# 22.3143655823

# %%
oe1=0.0
oe2=0.0
for i in range(10):
    from keras.models import Sequential
    from keras.layers import Dense, Activation
    m=Sequential()
    m.add(Dense(600,input_dim=2700))
    m.add(Activation('relu'))
    m.add(Dense(100))
    m.add(Activation('relu'))
    m.add(Dense(1))
    m.add(Activation('relu'))

    m.compile(loss='mean_absolute_percentage_error',optimizer='sgd')
    
    #print len(im)
    from sklearn.svm import SVR
    svr = SVR(kernel='rbf', C=1e3, gamma=0.1)

    
    trainx=[]
    trainy=[]
    testx=[]
    testy=[]
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            temp=[]
            for l in range(2700):
                temp.append(float(im[j][l])/255)
            trainx.append(temp)
            trainy.append([p[j]])
    for j in range(i*175,i*175 + 175):
        temp=[]
        for l in range(2700):
            temp.append(float(im[j][l])/255)
        testx.append(temp)
    #testx=[im[x]/255 for x in range(i*175,i*175 + 175)]
    for j in range(i*175,i*175 + 175):
        testy.append(p[j])
    #testy=[p[x] for x in range(i*175,i*175 + 175)]    
    print np.shape(trainx)
    m.fit(trainx,trainy, epochs=10, batch_size=32)
    tp=m.predict(trainx,batch_size=16)
    #print len(tp)
    newtrainx=[]
    k=0
    #print len(tp)
    for j in range(1750):
        if j < i*175 or j>=i*175 + 175:
            b=[tp[k][0]]
            b.append(w[j])
            b.append(h[j])
            b.append(c[j])
            newtrainx.append(b)
            k=k+1
    svr.fit(newtrainx,trainy)
    tp=m.predict(testx,batch_size=32)
    acc=0.0
    #print ty
    for j in range(len(tp)):
        acc+=(abs(testy[j]-tp[j])/testy[j])*100
    acc=acc/len(tp)
    print acc
    oe1+=acc
    
    newtest=[]
    k=0
    for j in range(i*175,i*175+175):
        b=[tp[k][0]]
        k=k+1
        b.append(w[j])
        b.append(h[j])
        b.append(c[j])
        newtest.append(b)
    ty=svr.predict(newtest)
    acc=0.0
    #print ty
    for j in range(len(ty)):
        acc+=(abs(testy[j]-ty[j])/testy[j])*100
    acc=acc/len(ty)
    print acc
    oe2+=acc
# Out:
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 0s - loss: 54.9342
# Epoch 2/10
# 1575/1575 [==============================] - 0s - loss: 28.3007
# Epoch 3/10
# 1575/1575 [==============================] - 0s - loss: 28.1020
# Epoch 4/10
#  - ETA: 0s - loss: 27.9968
# Epoch 5/10
# 1575/1575 [==============================] - 0s - loss: 26.9818
# Epoch 6/10
# 1575/1575 [==============================] - 0s - loss: 27.0590
# Epoch 7/10
# 1575/1575 [==============================] - 0s - loss: 26.1832
# Epoch 8/10
# 1575/1575 [==============================] - 0s - loss: 26.5467
# Epoch 9/10
# 1575/1575 [==============================] - 0s - loss: 26.5738
# Epoch 10/10
# 1575/1575 [==============================] - 0s - loss: 26.3587
# [ 29.87550735]
# 20.0107891795
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 0s - loss: 57.9420
# Epoch 2/10
# 1575/1575 [==============================] - 0s - loss: 29.1486
# Epoch 3/10
# 1575/1575 [==============================] - 0s - loss: 29.2001
# Epoch 4/10
# 1575/1575 [==============================] - 0s - loss: 28.4085
# Epoch 5/10
# 1575/1575 [==============================] - 0s - loss: 27.1990
# Epoch 6/10
# 1575/1575 [==============================] - 0s - loss: 27.1594
# Epoch 7/10
# 1575/1575 [==============================] - 0s - loss: 27.7244
# Epoch 8/10
# 1575/1575 [==============================] - 0s - loss: 27.5199
# Epoch 9/10
# 1575/1575 [==============================] - 0s - loss: 27.2014
# Epoch 10/10
# 1575/1575 [==============================] - 0s - loss: 27.1364
# [ 22.76504517]
# 25.9805900436
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 53.7178
# Epoch 2/10
# 1575/1575 [==============================] - 0s - loss: 29.5811
# Epoch 3/10
# 1575/1575 [==============================] - 0s - loss: 29.4378
#  - ETA: 0s - loss: 30.4012
# Epoch 4/10
# 1575/1575 [==============================] - 0s - loss: 27.5112
# Epoch 5/10
# 1575/1575 [==============================] - 0s - loss: 26.4215
# Epoch 6/10
# 1575/1575 [==============================] - 0s - loss: 26.4323
# Epoch 7/10
# 1575/1575 [==============================] - 0s - loss: 25.7081
# Epoch 8/10
# 1575/1575 [==============================] - 0s - loss: 25.1053
# Epoch 9/10
# 1575/1575 [==============================] - 0s - loss: 26.6275
# Epoch 10/10
# 1575/1575 [==============================] - 0s - loss: 26.1416
# [ 36.54751205]
# 19.3815449123
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 100.0000
# Epoch 2/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 3/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 4/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 5/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 6/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 7/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 8/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 9/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# Epoch 10/10
# 1575/1575 [==============================] - 0s - loss: 100.0000
# [ 100.]
# 21.1087726708
# (1575, 2700)
# Epoch 1/10
# 1575/1575 [==============================] - 1s - loss: 98.9409
# Epoch 2/10
# 1575/1575 [==============================] - 0s - loss: 32.7207
# Epoch 3/10
# 1575/1575 [==============================] - 0s - loss: 28.2642
# Epoch 4/10
# 1575/1575 [==============================] - 0s - loss: 27.6681
# Epoch 5/10
# 1575/1575 [==============================] - 0s - loss: 27.2647
# Epoch 6/10
# 1575/1575 [==============================] - 0s - loss: 27.2349
# Epoch 7/10
# 1575/1575 [==============================] - 0s - loss: 26.3889
# Epoch 8/10
# 1575/1575 [==============================] - 0s - loss: 25.8779
# Epoch 9/10
# 1575/1575 [==============================] - 0s - loss: 25.9497
# Epoch 10/10
# 1575/1575 [==============================] - 0s - loss: 25.8729
# [ 35.18238831]
# 46.7364630933

# %%
print oe1/10
print oe2/10
# Out:
# [ 48.73715973]
# 21.4495591463

# %%
print ty
# Out:
# [ 792.4425309   768.53839033  676.59174491  592.4112082   640.05853641
#   781.38047251  811.96914688  776.91484929  809.50655874  331.00476436
#   371.62278954  403.5966027   362.26467941  324.3859366   348.99773769
#   350.49588398  367.26611185  335.4591817   328.46266748  394.23117083
#   400.09292775  369.55942696  394.25884565  324.96797658  731.43432883
#   657.80205995  828.11365244  647.29142384  684.81288602  981.21289267
#   815.75002174  543.8716752   491.49937942  360.94420948  356.06939583
#   327.11756646  374.41022646  361.90935003  382.36761088  370.330859
#   555.46375483  911.82292724  585.65908578  507.76508145  709.18474183
#   782.92430192  635.22966112  699.95241884  690.09140519  624.15555223
#   563.75890059  790.78553547  749.99203309  597.20763552  355.28219253
#   487.80924209  882.84409368  706.21991354  786.88590381  625.17633303
#   486.5990475   694.4067499   846.84220612  684.79505767  750.00129679
#   344.1390945   510.95706964  378.12712319  461.2799192   519.76022449
#   332.4770303   365.80182091  520.92463109  734.3005856   520.92455855
#   406.6432765   330.50777665  626.98501498  363.34452118  325.89512243
#   320.76305914  359.98694588  311.19859128  423.5867186   320.91624582
